# %% [markdown]
# # 07 Modelling-Multiple linear Regression

# %% [markdown]
# ---

# %% [markdown]
# # Contents
#
# - [1.0 About Prophet Model](#1.0-About-Prophet-Model)
# - [2.0 Load Data](#2.0-Load-Data)
#     - [2.1 EUR/USD Data](#2.1-EUR/USD-Data)
#     - [2.2 Pattern Data](#2.2-Pattern-Data)
# - [3.0 Model](#3.0-Model)
#     - [3.1 Train/Test Split](#3.1-Train/Test-Split)
#     - [3.2 Fit Model](#3.2-Fit-Model)
#     - [3.3 Calculate Results](#3.3-Calculate-Results)
#     - [3.4 Run Model](#3.4-Run-Model)
# - [4.0 Results](#4.0-Results)
# - [5.0 Observations](#5.0-Observations)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import calendar

from sklearn.metrics import r2_score, mean_squared_error
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

from fbprophet import Prophet
from statsmodels.tools.eval_measures import rmse

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---

# %% [markdown]
# # 1.0  Model

# %% [markdown]
# About Prophet

# %% [markdown]
# More About Prophet

# %% [markdown]
# ---

# %% [markdown]
# # 2.0 Load Data

# %% [markdown]
# ## 2.1 EUR/USD Data

# %%
# read in the daily data
daily = pd.read_csv('/Users/stuartdaw/Documents/Capstone_data/data/resampled/eur-usd2daily.csv', 
                    index_col='date', parse_dates=True)

# %%
daily.head()
# Out:
#               open    high     low   close      mid  wk_mv_avg  mnth_mv_avg  \
# date
# 2000-07-14  0.9353  0.9389  0.9318  0.9383  0.93680    0.94522     0.948145
# 2000-07-17  0.9382  0.9402  0.9342  0.9360  0.93710    0.94217     0.947100
# 2000-07-18  0.9361  0.9368  0.9227  0.9256  0.93085    0.93785     0.945633
# 2000-07-19  0.9255  0.9270  0.9193  0.9246  0.92505    0.93366     0.944207
# 2000-07-20  0.9245  0.9342  0.9204  0.9325  0.92850    0.93166     0.943221
#
#             volatility_3_day  volatility_10_day  pct_chge_3_prds  \
# date
# 2000-07-14          0.003250           0.003387        -0.016431
# 2000-07-17          0.004282           0.003440        -0.009408
# 2000-07-18          0.003582           0.003797        -0.008151
# 2000-07-19          0.003915           0.003618        -0.012543
# 2000-07-20          0.005881           0.004167        -0.009177
#
#             pct_chge_5_prds  pct_chge_10_prds  height  height-1  height-2  \
# date
# 2000-07-14        -0.014102         -0.017514  0.0030    0.0062    0.0086
# 2000-07-17        -0.016013         -0.014875  0.0022    0.0030    0.0062
# 2000-07-18        -0.022678         -0.020519  0.0105    0.0022    0.0030
# 2000-07-19        -0.022146         -0.029125  0.0009    0.0105    0.0022
# 2000-07-20        -0.010655         -0.024531  0.0080    0.0009    0.0105
#
#             height-3  direction  gold_usd  gold_euro  marubozu  marubozu+1  \
# date
# 2000-07-14    0.0041        1.0      97.4      122.0         0         0.0
# 2000-07-17    0.0086       -1.0      98.1      123.3         0        -1.0
# 2000-07-18    0.0062       -1.0      98.3      123.8        -1         0.0
# 2000-07-19    0.0030       -1.0      97.0      123.3         0         1.0
# 2000-07-20    0.0022        1.0      97.1      123.3         1         0.0
#
#             marubozu-1  marubozu-2  day-1_open  day-2_open  day-3_open  \
# date
# 2000-07-14        -1.0        -1.0      0.9416      0.9503      0.9545
# 2000-07-17         0.0        -1.0      0.9353      0.9416      0.9503
# 2000-07-18         0.0         0.0      0.9382      0.9353      0.9416
# 2000-07-19        -1.0         0.0      0.9361      0.9382      0.9353
# 2000-07-20         0.0        -1.0      0.9255      0.9361      0.9382
#
#             day-1_high  day-2_high  day-3_high  day-1_low  day-2_low  \
# date
# 2000-07-14      0.9425      0.9517      0.9569     0.9330     0.9396
# 2000-07-17      0.9389      0.9425      0.9517     0.9318     0.9330
# 2000-07-18      0.9402      0.9389      0.9425     0.9342     0.9318
# 2000-07-19      0.9368      0.9402      0.9389     0.9227     0.9342
# 2000-07-20      0.9270      0.9368      0.9402     0.9193     0.9227
#
#             day-3_low  day-1_close  day-2_close  day-3_close  day+1_open  \
# date
# 2000-07-14     0.9496       0.9354       0.9417       0.9504      0.9382
# 2000-07-17     0.9396       0.9383       0.9354       0.9417      0.9361
# 2000-07-18     0.9330       0.9360       0.9383       0.9354      0.9255
# 2000-07-19     0.9318       0.9256       0.9360       0.9383      0.9245
# 2000-07-20     0.9342       0.9246       0.9256       0.9360      0.9324
#
#             day+1_high  day+1_low  day+1_close  day+2_high  day+2_low  \
# date
# 2000-07-14      0.9402     0.9342       0.9360      0.9368     0.9227
# 2000-07-17      0.9368     0.9227       0.9256      0.9270     0.9193
# 2000-07-18      0.9270     0.9193       0.9246      0.9342     0.9204
# 2000-07-19      0.9342     0.9204       0.9325      0.9384     0.9319
# 2000-07-20      0.9384     0.9319       0.9365      0.9367     0.9313
#
#             day+3_high  day+3_low  day+4_high  day+4_low  day+5_high  \
# date
# 2000-07-14      0.9270     0.9193      0.9342     0.9204      0.9384
# 2000-07-17      0.9342     0.9204      0.9384     0.9319      0.9367
# 2000-07-18      0.9384     0.9319      0.9367     0.9313      0.9433
# 2000-07-19      0.9367     0.9313      0.9433     0.9329      0.9450
# 2000-07-20      0.9433     0.9329      0.9450     0.9391      0.9444
#
#             day+5_low  exit_price  select  target      date+5
# date
# 2000-07-14     0.9319      0.9413       0  0.9402  2000-07-21
# 2000-07-17     0.9313      0.9338       0  0.9193  2000-07-24
# 2000-07-18     0.9329      0.9151       0  0.9193  2000-07-25
# 2000-07-19     0.9391      0.9237       0  0.9204  2000-07-26
# 2000-07-20     0.9314      0.9405       0  0.9450  2000-07-27

# %%
for count in range(4,16):
    daily['day-' + str(count) +'_mid'] = daily['mid'].shift(count)
    daily['day-' + str(count) +'_height'] = daily['height'].shift(count)

# %%
daily.head(20)
# Out:
#               open    high     low   close      mid  wk_mv_avg  mnth_mv_avg  \
# date
# 2000-08-04  0.9047  0.9103  0.9015  0.9088  0.90675    0.91649     0.933074
# 2000-08-07  0.9090  0.9114  0.9055  0.9083  0.90865    0.91307     0.931095
# 2000-08-08  0.9084  0.9084  0.8982  0.9010  0.90470    0.90958     0.928826
# 2000-08-09  0.9009  0.9028  0.8965  0.9020  0.90145    0.90648     0.926398
# 2000-08-10  0.9020  0.9098  0.9020  0.9087  0.90535    0.90538     0.924462
# 2000-08-11  0.9089  0.9145  0.9014  0.9029  0.90590    0.90521     0.922910
# 2000-08-21         0.0041     0.91085         0.0117     0.91695
# 2000-08-22         0.0007     0.90675         0.0041     0.91085
# 2000-08-23         0.0074     0.90865         0.0007     0.90675
# 2000-08-24         0.0011     0.90470         0.0074     0.90865
# 2000-08-25         0.0067     0.90145         0.0011     0.90470
# 2000-08-28         0.0060     0.90535         0.0067     0.90145
# 2000-08-29         0.0036     0.90590         0.0060     0.90535
# 2000-08-30         0.0094     0.90490         0.0036     0.90590
# 2000-08-31         0.0008     0.91140         0.0094     0.90490
#
#             day-13_height  day-14_mid  day-14_height  day-15_mid  \
# date
# 2000-08-04         0.0105     0.93710         0.0022     0.93680
# 2000-08-07         0.0009     0.93085         0.0105     0.93710
# 2000-08-08         0.0080     0.92505         0.0009     0.93085
# 2000-08-09         0.0041     0.92850         0.0080     0.92505
# 2000-08-10         0.0036     0.93445         0.0041     0.92850
# 2000-08-11         0.0083     0.93480         0.0036     0.93445
# 2000-08-14         0.0024     0.93705         0.0083     0.93480
# 2000-08-15         0.0115     0.94230         0.0024     0.93705
# 2000-08-16         0.0079     0.93765         0.0115     0.94230
# 2000-08-17         0.0033     0.92805         0.0079     0.93765
# 2000-08-18         0.0107     0.92575         0.0033     0.92805
# 2000-08-21         0.0001     0.92215         0.0107     0.92575
# 2000-08-22         0.0117     0.91695         0.0001     0.92215
# 2000-08-23         0.0041     0.91085         0.0117     0.91695
# 2000-08-24         0.0007     0.90675         0.0041     0.91085
# 2000-08-25         0.0074     0.90865         0.0007     0.90675
# 2000-08-28         0.0011     0.90470         0.0074     0.90865
# 2000-08-29         0.0067     0.90145         0.0011     0.90470
# 2000-08-30         0.0060     0.90535         0.0067     0.90145
# 2000-08-31         0.0036     0.90590         0.0060     0.90535
#
#             day-15_height
# date
# 2000-08-04         0.0030
# 2000-08-07         0.0022
# 2000-08-08         0.0105
# 2000-08-09         0.0009
# 2000-08-10         0.0080
# 2000-08-11         0.0041
# 2000-08-14         0.0036
# 2000-08-15         0.0083
# 2000-08-16         0.0024
# 2000-08-17         0.0115
# 2000-08-18         0.0079
# 2000-08-21         0.0033
# 2000-08-22         0.0107
# 2000-08-23         0.0001
# 2000-08-24         0.0117
# 2000-08-25         0.0041
# 2000-08-28         0.0007
# 2000-08-29         0.0074
# 2000-08-30         0.0011
# 2000-08-31         0.0067

# %%
daily.shape
# Out:
# (4612, 75)

# %%
daily.dropna(inplace=True)

# %%
daily.shape
# Out:
# (4597, 75)

# %%
strat_res = pd.read_csv('/Users/stuartdaw/Documents/Capstone_data/model_results/arima_results.csv', parse_dates=True)

# %%
strat_res.tail(20)
# Out:
#            name  strategy        date time_frame      RMSE       MSE  \
# 42  arima-0-1-0  marubozu  2012-07-25      daily  0.013808  0.000191
# 43  arima-0-1-0  marubozu  2012-12-05      daily  0.015200  0.000231
# 44  arima-0-1-0  marubozu  2013-05-23      daily  0.003633  0.000013
# 45  arima-0-1-0  marubozu  2013-08-02      daily  0.003621  0.000013
# 46  arima-0-1-0  marubozu  2014-09-19      daily  0.012922  0.000167
# 47  arima-0-1-0  marubozu  2014-12-11      daily  0.008296  0.000069
# 48  arima-0-1-0  marubozu  2015-02-05      daily  0.015147  0.000229
# 49  arima-0-1-0  marubozu  2015-06-29      daily  0.017357  0.000301
# 50  arima-0-1-0  marubozu  2016-01-06      daily  0.008007  0.000064
# 51  arima-0-1-0  marubozu  2016-01-20      daily  0.009116  0.000083
# 52  arima-0-1-0  marubozu  2016-08-22      daily  0.009183  0.000084
# 53  arima-0-1-0  marubozu  2017-01-06      daily  0.004991  0.000025
# 54  arima-0-1-0  marubozu  2017-01-18      daily  0.004499  0.000020
# 55  arima-0-1-0  marubozu  2017-02-17      daily  0.010258  0.000105
# 56  arima-0-1-0  marubozu  2018-06-26      daily  0.009154  0.000084
# 57  arima-0-1-0  marubozu  2018-09-14      daily  0.003028  0.000009
# 58  arima-0-1-0  marubozu  2018-10-22      daily  0.012050  0.000145
# 59  arima-0-1-0  marubozu  2018-12-10      daily  0.008124  0.000066
# 60  arima-0-1-0  marubozu  2019-01-31      daily  0.009717  0.000094
# 61  arima-0-1-0  marubozu  2019-02-13      daily  0.002301  0.000005
#
#    classification
# 42             tp
# 43             fn
# 44             tp
# 45             tp
# 46             fn
# 47             fn
# 48             tn
# 49             tn
# 50             fn
# 51             fn
# 52             fp
# 53             fn
# 54             tn
# 55             fn
# 56             fn
# 57             tn
# 58             fn
# 59             fn
# 60             fn
# 61             tn

# %%
len(strat_res)
# Out:
# 62

# %%
# Create features dataset

# %%
    # insert the signal to dataset
    train_test.insert(0, 'signal', model_info['signal'])

    # create start and end points for the test/train splits
    model_info['start'] = len(train_test)-5
    model_info['end'] = len(train_test)-1

# %%
daily_pattern = pd.read_csv('/Users/stuartdaw/Documents/Capstone_data/data/targets/daily_pattern2.csv', 
                           parse_dates=True)
daily_pattern.head()
# Out:
#   pattern_end
# 0  2000-10-11
# 1  2000-10-20
# 2  2001-04-05
# 3  2001-04-09
# 4  2001-08-20

# %%
features = daily[daily.index.isin(daily_pattern['pattern_end'])]
features.shape
#df[df.index.isin(my_list)]
# Out:
# (64, 75)

# %%
features = features[features.index.isin(strat_res['date'])]
features.shape
# Out:
# (62, 75)

# %%
results_series = list(strat_res['classification'])
features['ml_signal'] = results_series
features
# Out:
#                open     high      low    close       mid  wk_mv_avg  \
# date
# 2000-10-11  0.87330  0.87640  0.86440  0.86770  0.870500   0.870460
# 2000-10-20  0.84710  0.84750  0.83510  0.84010  0.843600   0.847740
# 2001-04-05  0.90660  0.90910  0.89430  0.89670  0.901650   0.890360
# 2001-04-09  0.90350  0.90510  0.89470  0.89650  0.900000   0.898610
# 2001-08-20  0.91780  0.92050  0.91130  0.91260  0.915200   0.911100
# ...             ...      ...      ...      ...       ...        ...
# 2018-09-14  1.16928  1.17215  1.16199  1.16357  1.166425   1.162073
# 2018-10-22  1.15144  1.15499  1.14530  1.14543  1.148435   1.150957
# 2018-12-10  1.14282  1.14398  1.13500  1.13690  1.139860   1.137008
# 2019-01-31  1.15026  1.15141  1.14356  1.14420  1.147230   1.143486
# 2019-02-13  1.13366  1.13395  1.12490  1.12800  1.130830   1.131878
#
# 2019-02-13       0.00606    1.147140        0.00626    1.143575
#
#             day-11_height  day-12_mid  day-12_height  day-13_mid  \
# date
# 2000-10-11        0.00710    0.878500        0.00580    0.870600
# 2000-10-20        0.00430    0.876100        0.00300    0.877600
# 2001-04-05        0.01320    0.904950        0.00970    0.898550
# 2001-04-09        0.00500    0.891850        0.00930    0.903000
# 2001-08-20        0.00130    0.882150        0.00010    0.881200
# ...                   ...         ...            ...         ...
# 2018-09-14        0.00367    1.169750        0.00056    1.168440
# 2018-10-22        0.00061    1.148930        0.00340    1.152605
# 2018-12-10        0.00679    1.140290        0.00212    1.138485
# 2019-01-31        0.00276    1.144495        0.00697    1.147795
# 2019-02-13        0.00085    1.142520        0.00126    1.136965
#
#             day-13_height  day-14_mid  day-14_height  day-15_mid  \
# date
# 2000-10-11        0.02180    0.853800        0.01160    0.848950
# 2000-10-20        0.00020    0.880200        0.00520    0.882050
# 2001-04-05        0.00330    0.897300        0.00100    0.903900
# 2001-04-09        0.01320    0.904950        0.00970    0.898550
# 2001-08-20        0.00180    0.878100        0.00460    0.875500
# ...                   ...         ...            ...         ...
# 2018-09-14        0.00208    1.165010        0.00478    1.159070
# 2018-10-22        0.01075    1.157500        0.00096    1.158325
# 2018-12-10        0.00147    1.141160        0.00682    1.142175
# 2019-01-31        0.00037    1.150235        0.00533    1.154365
# 2019-02-13        0.00985    1.135320        0.00658    1.137620
#
#             day-15_height ml_signal
# date
# 2000-10-11        0.00210        tp
# 2000-10-20        0.00150        tp
# 2001-04-05        0.01240        tp
# 2001-04-09        0.00330        tp
# 2001-08-20        0.00080        tp
# ...                   ...       ...
# 2018-09-14        0.00712        tn
# 2018-10-22        0.00259        fn
# 2018-12-10        0.00483        fn
# 2019-01-31        0.00295        fn
# 2019-02-13        0.00198        tn
#
# [62 rows x 76 columns]

# %%
features.groupby('direction').count()['open']
# Out:
# direction
# -1.0    36
#  1.0    26
# Name: open, dtype: int64

# %%
features.groupby('ml_signal').count()
# Out:
#            open  high  low  close  mid  wk_mv_avg  mnth_mv_avg  \
# ml_signal
# fn           27    27   27     27   27         27           27
# fp            4     4    4      4    4          4            4
# tn           18    18   18     18   18         18           18
# tp           13    13   13     13   13         13           13
#
#            volatility_3_day  volatility_10_day  pct_chge_3_prds  \
# ml_signal
# fn                       27                 27               27
# fp                        4                  4                4
# tn                       18                 18               18
# tp                       13                 13               13
#
#            pct_chge_5_prds  pct_chge_10_prds  height  height-1  height-2  \
# ml_signal
# fn                      27                27      27        27        27
# fp                       4                 4       4         4         4
# tn                      18                18      18        18        18
# tp                      13                13      13        13        13
#
#            height-3  direction  gold_usd  gold_euro  marubozu  marubozu+1  \
# ml_signal
# fn               27         27        27         27        27          27
# fp                4          4         4          4         4           4
# tn               18         18        18         18        18          18
# tp               13         13        13         13        13          13
#
#            marubozu-1  marubozu-2  day-1_open  day-2_open  day-3_open  \
# ml_signal
# fn                 27          27          27          27          27
# fp                  4           4           4           4           4
# tn                 18          18          18          18          18
# tp                 13          13          13          13          13
#
#            day-1_high  day-2_high  day-3_high  day-1_low  day-2_low  \
# ml_signal
# fn                 27          27          27         27         27
# fp                  4           4           4          4          4
# tn                 18          18          18         18         18
# tp                 13          13          13         13         13
#
#            day-3_low  day-1_close  day-2_close  day-3_close  day+1_open  \
# ml_signal
# fn                27           27           27           27          27
# fp                 4            4            4            4           4
# tn                18           18           18           18          18
# tp                13           13           13           13          13
#
#            day+1_high  day+1_low  day+1_close  day+2_high  day+2_low  \
# ml_signal
# fn                 27         27           27          27         27
# fp                  4          4            4           4          4
# tn                 18         18           18          18         18
# tp                 13         13           13          13         13
#
#            day+3_high  day+3_low  day+4_high  day+4_low  day+5_high  \
# ml_signal
# fn                 27         27          27         27          27
# fp                  4          4           4          4           4
# tn                 18         18          18         18          18
# tp                 13         13          13         13          13
#
#            day+5_low  exit_price  select  target  date+5  day-4_mid  \
# ml_signal
# fn                27          27      27      27      27         27
# fp                 4           4       4       4       4          4
# tn                18          18      18      18      18         18
# tp                13          13      13      13      13         13
#
#            day-4_height  day-5_mid  day-5_height  day-6_mid  day-6_height  \
# ml_signal
# fn                   27         27            27         27            27
# fp                    4          4             4          4             4
# tn                   18         18            18         18            18
# tp                   13         13            13         13            13
#
#            day-7_mid  day-7_height  day-8_mid  day-8_height  day-9_mid  \
# ml_signal
# fn                27            27         27            27         27
# fp                 4             4          4             4          4
# tn                18            18         18            18         18
# tp                13            13         13            13         13
#
#            day-9_height  day-10_mid  day-10_height  day-11_mid  day-11_height  \
# ml_signal
# fn                   27          27             27          27             27
# fp                    4           4              4           4              4
# tn                   18          18             18          18             18
# tp                   13          13             13          13             13
#
#            day-12_mid  day-12_height  day-13_mid  day-13_height  day-14_mid  \
# ml_signal
# fn                 27             27          27             27          27
# fp                  4              4           4              4           4
# tn                 18             18          18             18          18
# tp                 13             13          13             13          13
#
#            day-14_height  day-15_mid  day-15_height
# ml_signal
# fn                    27          27             27
# fp                     4           4              4
# tn                    18          18             18
# tp                    13          13             13

# %%
def convert_signal(row):
    if row['ml_signal'] == 'tp':
        return row['direction']
    else:
        return 0

# %%
features['ml_signal'] = features.apply(convert_signal, axis=1)

# %%
features.groupby('ml_signal').count()['open']
# Out:
# ml_signal
# -1.0     7
#  0.0    49
#  1.0     6
# Name: open, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 3.0 Model

# %% [markdown]
# ## 3.1 Train/Test Split

# %%
def create_train_test_split(date, time_series, model_info):

    # Get index of pattern and add 6 (so 5) extra rows for Test/train set
    test_end_loc = time_series.index.get_loc(date) + 6
    
    # Create train/test set using index loc of pattern 
    train_test = time_series.iloc[:test_end_loc]
    
    # Set target values
    target_value = time_series.loc[time_series.index == date,'exit_price'].item()
    
    # add target price to dataset
    train_test.insert(0, 'target_price', target_value)
    
    # Add Signal so it can be determined whether we expect the price to go up or down.
    model_info['signal'] = time_series.loc[date,'marubozu']
    
    # insert the signal to dataset
    train_test.insert(0, 'signal', model_info['signal'])
    
    # create start and end points for the test/train splits
    model_info['start'] = len(train_test)-5
    model_info['end'] = len(train_test)-1
    
    # create the train and data sets
    model_info['train'] = train_test.iloc[:model_info['start']]
    model_info['test'] = train_test.iloc[model_info['start']:]
    
    return model_info

# %% [markdown]
# ## 3.2 Fit Model

# %%
# Define a results dictionary to use to collect the results
results = {'algo':'','name':'','date':'', 'time_frame':'','success':0,'RMSE':0, 'MSE':0, 'classification':'' }

# %%
def train_arima(model_info, p=0, d=1, q=0):
    
    exog = np.column_stack([model_info['train']['mnth_mv_avg'], 
                            model_info['train']['wk_mv_avg'],
                            model_info['train']['volatility_3_day'],
                            model_info['train']['gold_euro'],
                            model_info['train']['gold_usd']])
    
    if model_info['signal'] == -1:
        model = ARIMA(model_info['train']['low'], exog=exog, order=(p,d,q))
    else:
        model = ARIMA(model_info['train']['high'], exog=exog, order=(p,d,q))

    results = model.fit()
    predictions = results.predict(start=model_info['start'], 
                                  end=model_info['end'], exog=exog,
                                  dynamic=True, 
                                  typ='levels').rename('ARIMA-0-1-0 Predictions')
    
    return results, predictions

# %% [markdown]
# ## 3.3 Calculate Results

# %%
def meet_threshold(row):
    if row['signal'] == -1 and row['low'] <= row['target_price']:
        return -1
    elif row['signal'] == 1 and row['high'] >= row['target_price']:
        return 1    
    else:
        return 0

# %%
def ml_decision(row):
    if row['direction'] == -1 and row['preds'] <= row['target_price']:
        return -1
    elif row['direction'] == 1 and row['preds'] >= row['target_price']:
        return 1    
    else:
        return 0

# %%
def create_results_outcomes_dataframe(test, predictions):    
    outcomes = pd.DataFrame()
    outcomes['low'] = test['low']
    outcomes['high'] = test['high']
    outcomes['preds'] = predictions.values
    outcomes['target_price'] = test['target_price']
    outcomes['direction'] = test['signal']
    outcomes['correct_call'] = test.apply(meet_threshold, axis=1)
    return outcomes

# %%
def print_chart(outcomes):
    if model_info['signal'] == -1:
        outcomes['low'].plot(legend=False, figsize=(12,8))
    else:
        outcomes['high'].plot(legend=False, figsize=(12,8))

    outcomes['preds'].plot(legend=False);
    outcomes['target_price'].plot(legend=False);

# %%
def get_results(model_info):
        
    if model_info['signal'] == -1:
        mse = mean_squared_error(model_info['test']['low'], predictions)
        rmse_res = rmse(model_info['test']['low'], predictions)
    else:
        mse = mean_squared_error(model_info['test']['high'], predictions)
        rmse_res = rmse(model_info['test']['high'], predictions)       
    
    return rmse_res, mse

# %%
def classify(outcomes):
    
    if max(outcomes['direction']) == 1:
        
        if max(outcomes['correct_call']) == 0 and max(outcomes['ml_correct_call']) == 0:
            return 'tn'
        elif max(outcomes['correct_call']) == 1 and max(outcomes['ml_correct_call']) == 1:
            return 'tp'
        elif max(outcomes['correct_call']) == 0 and max(outcomes['ml_correct_call']) == 1:
            return 'fp'
        elif max(outcomes['correct_call']) == 1 and max(outcomes['ml_correct_call']) == 0:
            return 'fn'
        
    elif max(outcomes['direction']) == -1:
        
        if min(outcomes['correct_call']) == 0 and min(outcomes['ml_correct_call']) == 0:
            return 'tn'
        elif min(outcomes['correct_call']) == -1 and min(outcomes['ml_correct_call']) == -1:
            return 'tp'
        elif min(outcomes['correct_call']) == 0 and min(outcomes['ml_correct_call']) == -1:
            return 'fp'
        elif min(outcomes['correct_call']) == -1 and min(outcomes['ml_correct_call']) == 0:
            return 'fn'
        
    else:
        return 'ERROR'

# %% [markdown]
# ## 3.4 Run Model
